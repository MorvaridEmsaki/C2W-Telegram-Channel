# %% [markdown]
# <a href="https://colab.research.google.com/github/MorvaridEmsaki/C2W-Telegram-Channel/blob/main/Thesis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Import Libraries

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from scipy import stats

import statsmodels.api as sm
import statsmodels.formula.api as smf

# %% [markdown]
# Load Dataset

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-5e954696-5972-482e-9930-b74ce01e72f1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5e954696-5972-482e-9930-b74ce01e72f1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv(next(iter(uploaded)))

# %%
df.head()
# Out:
#      id date_tehran                                               time  \
# 0   5.0   21-Nov-22  ##############################################...
# 1   6.0   21-Nov-22  ##############################################...
# 2  15.0   04-Dec-22  ##############################################...
# 3   9.0   04-Dec-22  ##############################################...
# 4  11.0   04-Dec-22  ##############################################...
#
#   Time Period weekday_tehran  Weekday Number  \
# 0     Morning         Monday             1.0
# 1     Morning         Monday             1.0
# 2       Night         Monday             1.0
# 3       Night         Sunday             7.0
# 4       Night         Sunday             7.0
#
#                                                 text  views  forwards  \
# 0  اولین و مهمترین قدم برای اخذ پذیرش تحصیلی داشت...   1123         7
# 1                                                NaN   1169         5
# ...

# %%
df.shape
# Out:
# (918, 23)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 23 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      918 non-null    float64
#  1   date_tehran             918 non-null    object
#  2   time                    918 non-null    object
#  3   Time Period             918 non-null    object
#  4   weekday_tehran          918 non-null    object
#  5   Weekday Number          918 non-null    float64
#  6   text                    909 non-null    object
#  7   views                   918 non-null    int64
#  8   forwards                918 non-null    int64
#  9   Consultation Inquiries  918 non-null    int64
#  10  has_media               918 non-null    int64
#  11  media_type              918 non-null    object
#  12  Country                 918 non-null    object
#  13  Degree                  918 non-null    object
# ...

# %%
df.isnull().sum()
# Out:
# id                          0
# date_tehran                 0
# time                        0
# Time Period                 0
# weekday_tehran              0
# Weekday Number              0
# text                        9
# views                       0
# forwards                    0
# Consultation Inquiries      0
# has_media                   0
# media_type                  0
# Country                     0
# Degree                      0
# Fund                        0
# QS_Rank                   290
# QS Available                0
# Bachelor                    0
# Master                      0
# PhD                         0
# Post Doc                    0
# Month                       0
# Month Number                0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#                 id  Weekday Number         views    forwards  \
# count   918.000000      918.000000    918.000000  918.000000
# mean    517.632898        3.802832   3428.391068   57.077342
# std     287.566724        2.010689   1655.627996   64.030983
# min       5.000000        1.000000    669.000000    0.000000
# 25%     273.250000        2.000000   2276.000000   21.000000
# 50%     514.500000        4.000000   3181.000000   37.000000
# 75%     770.750000        6.000000   4068.750000   71.000000
# max    1008.000000        7.000000  14626.000000  530.000000
#
#        Consultation Inquiries   has_media        Fund      QS_Rank  \
# count              918.000000  918.000000  918.000000   628.000000
# mean                 9.995643    0.686275    0.606754   396.248408
# std                  4.955195    0.464259    0.488737   407.027293
# min                  0.000000    0.000000    0.000000     2.000000
# 25%                  6.000000    0.000000    0.000000   103.000000
# ...

# %%
df["Country"].unique()
# Out:
# array(['Not Defined', 'Canada', 'United Kingdom', 'United States',
#        'Sweden', 'Australia', 'Italy', 'Netherlands', 'Spain',
#        'New Zealand', 'Denmark', 'Ireland', 'Germany', 'France', 'Japan',
#        'Austria', 'Taiwan', 'Singapore', 'China', 'Turkey', 'Belgium',
#        'Norway', 'Switzerland', 'Qatar', 'UAE', 'Malaysia', 'Romania',
#        'South Korea', 'Poland', 'Hungary', 'Saudi Arabia', 'Finland',
#        'Thailand'], dtype=object)

# %%
df["Degree"].unique()
# Out:
# array(['Not Defined', 'Bachelor', 'PhD', 'Postdoc', 'Bachelor; Master',
#        'Postdoc; Bachelor; Master', 'Master; PhD',
#        'Bachelor; Master; PhD', 'Master', 'Postdoc; Master'], dtype=object)

# %%
df["media_type"].unique()
# Out:
# array(['No Media', 'Photo', 'URL', 'Poll', 'Document'], dtype=object)

# %%
df["Month"].unique()
# Out:
# array(['November', 'December', 'January', 'February', 'March', 'April',
#        'May', 'June', 'July', 'August', 'September', 'October'],
#       dtype=object)

# %%
df["Country"].value_counts()
# Out:
# Country
# United States     164
# United Kingdom    137
# Canada            118
# Not Defined       115
# Australia          74
# Germany            62
# Sweden             28
# Netherlands        27
# Ireland            21
# Switzerland        18
# Italy              17
# France             16
# New Zealand        15
# Belgium            14
# Taiwan             12
# Austria            12
# Denmark            11
# Norway              8
# Malaysia            6
# Qatar               5
# Spain               5
# Romania             5
# Turkey              5
# China               5
# Japan               4
# Singapore           3
# UAE                 2
# South Korea         2
# Saudi Arabia        2
# Finland             2
# Poland              1
# Hungary             1
# Thailand            1
# Name: count, dtype: int64

# %%
df["media_type"].value_counts()
# Out:
# media_type
# Photo       337
# No Media    288
# URL         281
# Poll          7
# Document      5
# Name: count, dtype: int64

# %% [markdown]
# Variable Classification

# %%
df.columns = (
    df.columns
      .str.strip()
      .str.lower()
      .str.replace(" ", "_")
)

df.columns.tolist()
# Out:
# ['id',
#  'date_tehran',
#  'time',
#  'time_period',
#  'weekday_tehran',
#  'weekday_number',
#  'text',
#  'views',
#  'forwards',
#  'consultation_inquiries',
#  'has_media',
#  'media_type',
#  'country',
#  'degree',
#  'fund',
#  'qs_rank',
#  'qs_available',
#  'bachelor',
#  'master',
#  'phd',
#  'post_doc',
#  'month',
#  'month_number']

# %%
df.dtypes
# Out:
# id                        float64
# date_tehran                object
# time                       object
# time_period                object
# weekday_tehran             object
# weekday_number            float64
# text                       object
# views                       int64
# forwards                    int64
# consultation_inquiries      int64
# has_media                   int64
# media_type                 object
# country                    object
# degree                     object
# fund                        int64
# qs_rank                   float64
# qs_available                int64
# bachelor                    int64
# master                      int64
# phd                         int64
# post_doc                    int64
# month                      object
# month_number                int64
# dtype: object

# %%
df["weekday_number"] = df["weekday_number"].astype(int)
